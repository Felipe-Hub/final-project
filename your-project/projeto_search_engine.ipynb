# %%
import pandas as pd
import numpy as np
import pickle
import gensim
import nltk
import json
import re

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %% [markdown]
# #### Cleaning functions

# %%
def clean_up(s):
    words = re.findall('[^\d\W]+', str(s))
    words = [w.lower() for w in words if not w.startswith('http://') and len(w)>2]
    return ' '.join(words)
 
def stopwords(s):
    stop = pd.read_csv('stop.txt', sep=' ')['stopwords']
    return [word for word in s if word not in stop]

# tagging
def tagging(l):
    # importing trainned tagger (for portuguese)
    f = open('tagger.pickle', 'rb')
    tagger = pickle.load(f)
    f.close()
    tagged = tagger.tag(l)
    return [w for w,t in tagged if t == 'NOUN' or t == 'ADJ']

def set_up(s):
    s = clean_up(s)
    s = stopwords(s)
    return tagging(s)

# %% [markdown]
# #### Doc2Vec training function

# %%
# to bypass an issue with the 64bit python version, i had to add the following function
def hash32(value):
    return hash(value) & 0xffffffff


# the funciont will take the word Series to train the model doc by doc
def doc2vec_trainer(ws, model_doc, fname, c=0):
    for i in range(len(ws)):
        model_doc.train([TaggedDocument(ws[i], [c])], total_examples=model_doc.corpus_count,
                         epochs=50, report_delay=99999)
        model_doc.alpha -= 0.0002 # adjusting the learning rate
        model_doc.save(fname)
        c+=1
        print('Learned {} from {}!'.format(c, len(ws)))
    print('Success! Model updated.')
    return model_doc

# %% [markdown]
# #### Taking only meaningfull words
# Only stemming is not enough, will use the pos_tags trained to choose only meaningfull words, giving a better search result.

# %%
# importing and pre processing data
with open('labelled.json') as json_data:
    data = json.load(json_data)
    
df = pd.DataFrame.from_dict(data)

# %%
allwords = df['main'].apply(clean_up).str.split()
# Out:
# [['acordo',
#   'com',
#   'despacho',
#   'proferido',
#   'nos',
#   'autos',
#   'presente',
#   'caso',
#   'que',
#   'decisão',
#   'condenação',
#   'por',
#   'litigância',
#   'integra',
#   'decisão',
#   'que',
#   'põe',
#   'termo',
#   'processo',
#   'não',
#   'está',
#   'causa',
#   'uma',
#   'decisão',
#   'interlocutória',
#   'mas',
#   'antes',
#   'uma',
#   'parte',
#   'extensão',
#   'decisão',
#   'mérito',
#   'assim',
#   'ainda',
#   'que',
#   'não',
#   'ignore',
#   'existirem',
#   'esse',
#   'respeito',
#   'divergências',
#   'jurisprudência',
#   'stj',
#   'considerou',
#   'ser',
#   'decisão',
#   'recorrível',
#   'nos',
#   'termos',
#   'gerais',
#   'art',
#   'cpc',
#   'incindindo',
#   'decisão',
#   'condenação',
#   'por',
#   'litigância',
#   'sobre',
#   'representantes',
#   'legais',
#   'autora',
#   'actos',
#   'notificação',
#   'própria',
#   'sociedade',
#   'autora',
#   'não',
#   'podem',
#   'valer',
#   'como',
#   'notificação',
#   'pessoal',
#   'dos',
#   'seus',
#   'representantes',
#   'legais',
#   'nem',
#   'tampouco',
#   'conhecimento',
#   'pessoal',
#   'que',
#   'estes',
#   'possam',
#   'ter',
#   'dos',
#   'factos',
#   'provados',
#   'relevantes',
#   'nos',
#   'quais',
#   'sobredita',
#   'condenação',
#   'fundou',
#   'pode',
#   'suprir',
#   'falta',
#   'notificação',
#   'pessoal',
#   'tal',
#   'falta',
#   'tiver',
#   'ocorrido',
#   'iii',
#   'assim',
#   'comprovando',
#   'que',
#   'dos',
#   'recorrentes',
#   'não',
#   'foi',
#   'nominalmente',
#   'notificado',
#   'data',
#   'notificação',
#   'dos',
#   'despachos',
#   'causa',
#   'não',
#   'era',
#   'representante',
#   'legal',
#   'autora',
#   'iii',
#   'não',
#   'veio',
#   'aos',
#   'autos',
#   'apresentar',
#   'resposta',
#   'aos',
#   'despachos',
#   'instância',
#   'que',
#   'ordenaram',
#   'notificação',
#   'representante',
#   'legal',
#   'autora',
#   'forçoso',
#   'concluir',
#   'não',
#   'ter',
#   'mesmo',
#   'recorrente',
#   'sido',
#   'pessoal',
#   'devidamente',
#   'notificado',
#   'compulsado',
#   'processo',
#   'verifica',
#   'que',
#   'por',
#   'acórdão',
#   'anterior',
#   'relação',
#   'foi',
#   'definida',
#   'não',
#   'impugnada',
#   'aplicação',
#   'regime',
#   'condenação',
#   'por',
#   'litigância',
#   'anterior',
#   'reforma',
#   'cpc',
#   'introduzida',
#   'pela',
#   'lei',
#   'acordo',
#   'com',
#   'qual',
#   'quando',
#   'parte',
#   'for',
#   'uma',
#   'pessoa',
#   'colectiva',
#   'responsabilidade',
#   'pelas',
#   'custas',
#   'multa',
#   'indemnização',
#   'inerentes',
#   'condenação',
#   'recai',
#   'sobre',
#   'representante',
#   'legal',
#   'mesma',
#   'medida',
#   'que',
#   'ora',
#   'recorrentes',
#   'primeira',
#   'vez',
#   'que',
#   'vieram',
#   'processo',
#   'não',
#   'invocaram',
#   'qualquer',
#   'nulidade',
#   'processual',
#   'designadamente',
#   'pelo',
#   'facto',
#   'direito',
#   'aplicável',
#   'ter',
#   'sido',
#   'definido',
#   'antes',
#   'terem',
#   'sido',
#   'pessoalmente',
#   'notificados',
#   'não',
#   'lhes',
#   'tendo',
#   'sido',
#   'dada',
#   'oportunidade',
#   'pronunciarem',
#   'sobre',
#   'questão',
#   'própria',
#   'determinação',
#   'tal',
#   'regime',
#   'formou',
#   'esse',
#   'respeito',
#   'caso',
#   'julgado',
#   'formal',
#   'quanto',
#   'alegada',
#   'inconstitucionalidade',
#   'interpretação',
#   'aplicação',
#   'regime',
#   'dos',
#   'arts',
#   'cpc',
#   'antigo',
#   'por',
#   'violação',
#   'princípio',
#   'retroactividade',
#   'das',
#   'normas',
#   'sancionatórias',
#   'conteúdo',
#   'mais',
#   'favorável',
#   'mostra',
#   'evidente',
#   'partir',
#   'conclusão',
#   'ponto',
#   'que',
#   'acórdão',
#   'recorrido',
#   'não',
#   'interpretou',
#   'nem',
#   'aplicou',
#   'normas',
#   'causa',
#   'antes',
#   'limitou',
#   'considerar',
#   'ter',
#   'formado',
#   'caso',
#   'julgado',
#   'formal',
#   'respeito',
#   'aplicação',
#   'tais',
#   'normas',
#   'pelo',
#   'que',
#   'não',
#   'padece',
#   'acórdão',
#   'recorrido',
#   'invocada',
#   'inconstitucionalidade']]

# %%
with open('tag_stems.json') as json_data:
    data_stem = json.load(json_data)
    
stemmed = {k:' '.join(v) for k,v in data_stem.items()}
df_stem = pd.DataFrame.from_dict(stemmed, orient='index')
words_stem = df_stem[0].apply(lambda x: x.split())

# %% [markdown]
# #### Training Doc2Vec

# %%
# training

model_doc = Doc2Vec([TaggedDocument(allwords[0], [0])], vector_size=300, window=5, min_count=1, dbow_words=1,
                                                          workers=3, hashfxn=hash32, alpha=0.001, min_alpha=0.00025)

# %%
fname = "d2v_trainned_allwords.model"
model_doc.save(fname)

# %%
doc2vec_trainer(allwords, model_doc, fname)
#doc2vec_trainer(words_stem, words_stem, model_doc, fname)
# Out:
# Learned 1 from 9848!
# Learned 2 from 9848!
# Learned 3 from 9848!
# Learned 4 from 9848!
# Learned 5 from 9848!
# Learned 6 from 9848!
# Learned 7 from 9848!
# Learned 8 from 9848!
# Learned 9 from 9848!
# Learned 10 from 9848!
# Learned 11 from 9848!
# Learned 12 from 9848!
# Learned 13 from 9848!
# Learned 14 from 9848!
# Learned 15 from 9848!
# Learned 16 from 9848!
# Learned 17 from 9848!
# Learned 18 from 9848!
# Learned 19 from 9848!
# Learned 20 from 9848!
# Learned 21 from 9848!
# Learned 22 from 9848!
# Learned 23 from 9848!
# Learned 24 from 9848!
# Learned 25 from 9848!
# Learned 26 from 9848!
# Learned 27 from 9848!
# Learned 28 from 9848!
# Learned 29 from 9848!
# Learned 30 from 9848!
# Learned 31 from 9848!
# Learned 32 from 9848!
# Learned 33 from 9848!
# Learned 34 from 9848!
# Learned 35 from 9848!
# Learned 36 from 9848!
# Learned 37 from 9848!
# Learned 38 from 9848!
# Learned 39 from 9848!
# Learned 40 from 9848!
# Learned 41 from 9848!
# Learned 42 from 9848!
# Learned 43 from 9848!
# Learned 44 from 9848!
# Learned 45 from 9848!
# Learned 46 from 9848!
# Learned 47 from 9848!
# Learned 48 from 9848!
# Learned 49 from 9848!
# Learned 50 from 9848!
# Learned 51 from 9848!
# Learned 52 from 9848!
# Learned 53 from 9848!
# Learned 54 from 9848!
# Learned 55 from 9848!
# Learned 56 from 9848!
# Learned 57 from 9848!
# Learned 58 from 9848!
# Learned 59 from 9848!
# Learned 60 from 9848!
# Learned 61 from 9848!
# Learned 62 from 9848!
# Learned 63 from 9848!
# Learned 64 from 9848!
# Learned 65 from 9848!
# Learned 66 from 9848!
# Learned 67 from 9848!
# Learned 68 from 9848!
# Learned 69 from 9848!
# Learned 70 from 9848!
# Learned 71 from 9848!
# Learned 72 from 9848!
# Learned 73 from 9848!
# Learned 74 from 9848!
# Learned 75 from 9848!
# Learned 76 from 9848!
# Learned 77 from 9848!
# Learned 78 from 9848!
# Learned 79 from 9848!
# Learned 80 from 9848!
# Learned 81 from 9848!
# Learned 82 from 9848!
# Learned 83 from 9848!
# Learned 84 from 9848!
# Learned 85 from 9848!
# Learned 86 from 9848!
# Learned 87 from 9848!
# Learned 88 from 9848!
# Learned 89 from 9848!
# Learned 90 from 9848!
# Learned 91 from 9848!
# Learned 92 from 9848!
# Learned 93 from 9848!
# Learned 94 from 9848!
# Learned 95 from 9848!
# Learned 96 from 9848!
# Learned 97 from 9848!
# Learned 98 from 9848!
# Learned 99 from 9848!
# Learned 100 from 9848!
# Learned 101 from 9848!
# Learned 102 from 9848!
# Learned 103 from 9848!
# Learned 104 from 9848!
# Learned 105 from 9848!
# Learned 106 from 9848!
# Learned 107 from 9848!
# Learned 108 from 9848!
# Learned 109 from 9848!
# Learned 110 from 9848!
# Learned 111 from 9848!
# Learned 112 from 9848!
# Learned 113 from 9848!
# Learned 114 from 9848!
# Learned 115 from 9848!
# Learned 116 from 9848!
# Learned 117 from 9848!
# Learned 118 from 9848!
# Learned 119 from 9848!
# Learned 120 from 9848!
# Learned 121 from 9848!
# Learned 122 from 9848!
# Learned 123 from 9848!
# Learned 124 from 9848!
# Learned 125 from 9848!
# Learned 126 from 9848!
# Learned 127 from 9848!
# Learned 128 from 9848!
# Learned 129 from 9848!
# Learned 130 from 9848!
# Learned 131 from 9848!
# Learned 132 from 9848!
# Learned 133 from 9848!
# Learned 134 from 9848!
# Learned 135 from 9848!
# Learned 136 from 9848!
# Learned 137 from 9848!
# Learned 138 from 9848!
# Learned 139 from 9848!
# Learned 140 from 9848!
# Learned 141 from 9848!
# Learned 142 from 9848!
# Learned 143 from 9848!
# Learned 144 from 9848!
# Learned 145 from 9848!
# Learned 146 from 9848!
# Learned 147 from 9848!
# Learned 148 from 9848!
# Learned 149 from 9848!
# Learned 150 from 9848!
# Learned 151 from 9848!
# Learned 152 from 9848!
# Learned 153 from 9848!
# Learned 154 from 9848!
# Learned 155 from 9848!
# Learned 156 from 9848!
# Learned 157 from 9848!
# Learned 158 from 9848!
# Learned 159 from 9848!
# Learned 160 from 9848!
# Learned 161 from 9848!
# Learned 162 from 9848!
# Learned 163 from 9848!
# Learned 164 from 9848!
# Learned 165 from 9848!
# Learned 166 from 9848!
# Learned 167 from 9848!
# Learned 168 from 9848!
# Learned 169 from 9848!
# Learned 170 from 9848!
# Learned 171 from 9848!
# Learned 172 from 9848!
# Learned 173 from 9848!
# Learned 174 from 9848!
# Learned 175 from 9848!
# Learned 176 from 9848!
# Learned 177 from 9848!
# Learned 178 from 9848!
# Learned 179 from 9848!
# Learned 180 from 9848!
# Learned 181 from 9848!
# Learned 182 from 9848!
# Learned 183 from 9848!
# Learned 184 from 9848!
# Learned 185 from 9848!
# Learned 186 from 9848!
# Learned 187 from 9848!
# Learned 188 from 9848!
# Learned 189 from 9848!
# Learned 190 from 9848!
# Learned 191 from 9848!
# Learned 192 from 9848!
# Learned 193 from 9848!
# Learned 194 from 9848!
# Learned 195 from 9848!
# Learned 196 from 9848!
# Learned 197 from 9848!
# Learned 198 from 9848!
# Learned 199 from 9848!
# Learned 200 from 9848!
# Learned 201 from 9848!
# Learned 202 from 9848!
# Learned 203 from 9848!
# Learned 204 from 9848!
# Learned 205 from 9848!
# Learned 206 from 9848!
# Learned 207 from 9848!
# Learned 208 from 9848!
# Learned 209 from 9848!
# Learned 210 from 9848!
# Learned 211 from 9848!
# Learned 212 from 9848!
# Learned 213 from 9848!
# Learned 214 from 9848!
# Learned 215 from 9848!
# Learned 216 from 9848!
# Learned 217 from 9848!
# Learned 218 from 9848!
# Learned 219 from 9848!
# Learned 220 from 9848!
# Learned 221 from 9848!
# Learned 222 from 9848!
# Learned 223 from 9848!
# Learned 224 from 9848!
# Learned 225 from 9848!
# Learned 226 from 9848!
# Learned 227 from 9848!
# Learned 228 from 9848!
# Learned 229 from 9848!
# Learned 230 from 9848!
# Learned 231 from 9848!
# Learned 232 from 9848!
# Learned 233 from 9848!
# Learned 234 from 9848!
# Learned 235 from 9848!
# Learned 236 from 9848!
# Learned 237 from 9848!
# Learned 238 from 9848!
# Learned 239 from 9848!
# Learned 240 from 9848!
# Learned 241 from 9848!
# Learned 242 from 9848!
# Learned 243 from 9848!
# Learned 244 from 9848!
# Learned 245 from 9848!
# Learned 246 from 9848!
# Learned 247 from 9848!
# Learned 248 from 9848!
# Learned 249 from 9848!
# Learned 250 from 9848!
# Learned 251 from 9848!
# Learned 252 from 9848!
# Learned 253 from 9848!
# Learned 254 from 9848!
# Learned 255 from 9848!
# Learned 256 from 9848!
# Learned 257 from 9848!
# Learned 258 from 9848!
# Learned 259 from 9848!
# Learned 260 from 9848!
# Learned 261 from 9848!
# Learned 262 from 9848!
# Learned 263 from 9848!
# Learned 264 from 9848!
# Learned 265 from 9848!
# Learned 266 from 9848!
# Learned 267 from 9848!
# Learned 268 from 9848!
# Learned 269 from 9848!
# Learned 270 from 9848!
# Learned 271 from 9848!
# Learned 272 from 9848!
# Learned 273 from 9848!
# Learned 274 from 9848!
# Learned 275 from 9848!
# Learned 276 from 9848!
# Learned 277 from 9848!
# Learned 278 from 9848!
# Learned 279 from 9848!
# Learned 280 from 9848!
# Learned 281 from 9848!
# Learned 282 from 9848!
# Learned 283 from 9848!
# Learned 284 from 9848!
# Learned 285 from 9848!
# Learned 286 from 9848!
# Learned 287 from 9848!
# Learned 288 from 9848!
# Learned 289 from 9848!
# Learned 290 from 9848!
# Learned 291 from 9848!
# Learned 292 from 9848!
# Learned 293 from 9848!
# Learned 294 from 9848!
# Learned 295 from 9848!
# Learned 296 from 9848!
# Learned 297 from 9848!
# Learned 298 from 9848!
# Learned 299 from 9848!
# Learned 300 from 9848!
# Learned 301 from 9848!
# Learned 302 from 9848!
# Learned 303 from 9848!
# Learned 304 from 9848!
# Learned 305 from 9848!
# Learned 306 from 9848!
# Learned 307 from 9848!
# Learned 308 from 9848!
# Learned 309 from 9848!
# Learned 310 from 9848!
# Learned 311 from 9848!
# Learned 312 from 9848!
# Learned 313 from 9848!
# Learned 314 from 9848!
# Learned 315 from 9848!
# Learned 316 from 9848!
# Learned 317 from 9848!
# Learned 318 from 9848!
# Learned 319 from 9848!
# Learned 320 from 9848!
# Learned 321 from 9848!
# Learned 322 from 9848!
# Learned 323 from 9848!
# Learned 324 from 9848!
# Learned 325 from 9848!
# Learned 326 from 9848!
# Learned 327 from 9848!
# Learned 328 from 9848!
# Learned 329 from 9848!
# Learned 330 from 9848!
# Learned 331 from 9848!
# Learned 332 from 9848!
# Learned 333 from 9848!
# Learned 334 from 9848!
# Learned 335 from 9848!
# Learned 336 from 9848!
# Learned 337 from 9848!
# Learned 338 from 9848!
# Learned 339 from 9848!
# Learned 340 from 9848!
# Learned 341 from 9848!
# Learned 342 from 9848!
# Learned 343 from 9848!
# Learned 344 from 9848!
# Learned 345 from 9848!
# Learned 346 from 9848!
# Learned 347 from 9848!
# Learned 348 from 9848!
# Learned 349 from 9848!
# Learned 350 from 9848!
# Learned 351 from 9848!
# Learned 352 from 9848!
# Learned 353 from 9848!
# Learned 354 from 9848!
# Learned 355 from 9848!
# Learned 356 from 9848!
# Learned 357 from 9848!
# Learned 358 from 9848!
# Learned 359 from 9848!
# Learned 360 from 9848!
# Learned 361 from 9848!
# Learned 362 from 9848!
# Learned 363 from 9848!
# Learned 364 from 9848!
# Learned 365 from 9848!
# Learned 366 from 9848!
# Learned 367 from 9848!
# Learned 368 from 9848!
# Learned 369 from 9848!
# Learned 370 from 9848!
# Learned 371 from 9848!
# Learned 372 from 9848!
# Learned 373 from 9848!
# Learned 374 from 9848!
# Learned 375 from 9848!
# Learned 376 from 9848!
# Learned 377 from 9848!
# Learned 378 from 9848!
# Learned 379 from 9848!
# Learned 380 from 9848!
# Learned 381 from 9848!
# Learned 382 from 9848!
# Learned 383 from 9848!
# Learned 384 from 9848!
# Learned 385 from 9848!
# Learned 386 from 9848!
# Learned 387 from 9848!
# Learned 388 from 9848!
# Learned 389 from 9848!
# Learned 390 from 9848!
# Learned 391 from 9848!
# Learned 392 from 9848!
# Learned 393 from 9848!
# Learned 394 from 9848!
# Learned 395 from 9848!
# Learned 396 from 9848!
# Learned 397 from 9848!
# Learned 398 from 9848!
# Learned 399 from 9848!
# Learned 400 from 9848!
# Learned 401 from 9848!
# Learned 402 from 9848!
# Learned 403 from 9848!
# Learned 404 from 9848!
# Learned 405 from 9848!
# Learned 406 from 9848!
# Learned 407 from 9848!
# Learned 408 from 9848!
# Learned 409 from 9848!
# Learned 410 from 9848!
# Learned 411 from 9848!
# Learned 412 from 9848!
# Learned 413 from 9848!
# Learned 414 from 9848!
# Learned 415 from 9848!
# Learned 416 from 9848!
# Learned 417 from 9848!
# Learned 418 from 9848!
# Learned 419 from 9848!
# Learned 420 from 9848!
# Learned 421 from 9848!
# Learned 422 from 9848!
# Learned 423 from 9848!
# Learned 424 from 9848!
# Learned 425 from 9848!
# Learned 426 from 9848!
# Learned 427 from 9848!
# Learned 428 from 9848!
# Learned 429 from 9848!
# Learned 430 from 9848!
# Learned 431 from 9848!
# Learned 432 from 9848!
# Learned 433 from 9848!
# Learned 434 from 9848!
# Learned 435 from 9848!
# Learned 436 from 9848!
# Learned 437 from 9848!
# Learned 438 from 9848!
# Learned 439 from 9848!
# Learned 440 from 9848!
# Learned 441 from 9848!
# Learned 442 from 9848!
# Learned 443 from 9848!
# Learned 444 from 9848!
# Learned 445 from 9848!
# Learned 446 from 9848!
# Learned 447 from 9848!
# Learned 448 from 9848!
# Learned 449 from 9848!
# Learned 450 from 9848!
# Learned 451 from 9848!
# Learned 452 from 9848!
# Learned 453 from 9848!
# Learned 454 from 9848!
# Learned 455 from 9848!
# Learned 456 from 9848!
# Learned 457 from 9848!
# Learned 458 from 9848!
# Learned 459 from 9848!
# Learned 460 from 9848!
# Learned 461 from 9848!
# Learned 462 from 9848!
# Learned 463 from 9848!
# Learned 464 from 9848!
# Learned 465 from 9848!
# Learned 466 from 9848!
# Learned 467 from 9848!
# Learned 468 from 9848!
# Learned 469 from 9848!
# Learned 470 from 9848!
# Learned 471 from 9848!
# Learned 472 from 9848!
# Learned 473 from 9848!
# Learned 474 from 9848!
# Learned 475 from 9848!
# Learned 476 from 9848!
# Learned 477 from 9848!
# Learned 478 from 9848!
# Learned 479 from 9848!
# Learned 480 from 9848!
# Learned 481 from 9848!
# Learned 482 from 9848!
# Learned 483 from 9848!
# Learned 484 from 9848!
# Learned 485 from 9848!
# Learned 486 from 9848!
# Learned 487 from 9848!
# Learned 488 from 9848!
# Learned 489 from 9848!
# Learned 490 from 9848!
# Learned 491 from 9848!
# Learned 492 from 9848!
# Learned 493 from 9848!
# Learned 494 from 9848!
# Learned 495 from 9848!
# Learned 496 from 9848!
# Learned 497 from 9848!
# Learned 498 from 9848!
# Learned 499 from 9848!
# Learned 500 from 9848!
# Learned 501 from 9848!
# Learned 502 from 9848!
# Learned 503 from 9848!
# Learned 504 from 9848!
# Learned 505 from 9848!
# Learned 506 from 9848!
# Learned 507 from 9848!
# Learned 508 from 9848!
# Learned 509 from 9848!
# Learned 510 from 9848!
# Learned 511 from 9848!
# Learned 512 from 9848!
# Learned 513 from 9848!
# Learned 514 from 9848!
# Learned 515 from 9848!
# Learned 516 from 9848!
# Learned 517 from 9848!
# Learned 518 from 9848!
# Learned 519 from 9848!
# Learned 520 from 9848!
# Learned 521 from 9848!
# Learned 522 from 9848!
# Learned 523 from 9848!
# Learned 524 from 9848!
# Learned 525 from 9848!
# Learned 526 from 9848!
# Learned 527 from 9848!
# Learned 528 from 9848!
# Learned 529 from 9848!
# Learned 530 from 9848!
# Learned 531 from 9848!
# Learned 532 from 9848!
# Learned 533 from 9848!
# Learned 534 from 9848!
# Learned 535 from 9848!
# Learned 536 from 9848!
# Learned 537 from 9848!
# Learned 538 from 9848!
# Learned 539 from 9848!
# Learned 540 from 9848!
# Learned 541 from 9848!
# Learned 542 from 9848!
# Learned 543 from 9848!
# Learned 544 from 9848!
# Learned 545 from 9848!
# Learned 546 from 9848!
# Learned 547 from 9848!
# Learned 548 from 9848!
# Learned 549 from 9848!
# Learned 550 from 9848!
# Learned 551 from 9848!
# Learned 552 from 9848!
# Learned 553 from 9848!
# Learned 554 from 9848!
# Learned 555 from 9848!
# Learned 556 from 9848!
# Learned 557 from 9848!
# Learned 558 from 9848!
# Learned 559 from 9848!
# Learned 560 from 9848!
# Learned 561 from 9848!
# Learned 562 from 9848!
# Learned 563 from 9848!
# Learned 564 from 9848!
# Learned 565 from 9848!
# Learned 566 from 9848!
# Learned 567 from 9848!
# Learned 568 from 9848!
# Learned 569 from 9848!
# Learned 570 from 9848!
# Learned 571 from 9848!
# Learned 572 from 9848!
# Learned 573 from 9848!
# Learned 574 from 9848!
# Learned 575 from 9848!
# Learned 576 from 9848!
# Learned 577 from 9848!
# Learned 578 from 9848!
# Learned 579 from 9848!
# Learned 580 from 9848!
# Learned 581 from 9848!
# Learned 582 from 9848!
# Learned 583 from 9848!
# Learned 584 from 9848!
# Learned 585 from 9848!
# Learned 586 from 9848!
# Learned 587 from 9848!
# Learned 588 from 9848!
# Learned 589 from 9848!
# Learned 590 from 9848!
# Learned 591 from 9848!
# Learned 592 from 9848!
# Learned 593 from 9848!
# Learned 594 from 9848!
# Learned 595 from 9848!
# Learned 596 from 9848!
# Learned 597 from 9848!
# Learned 598 from 9848!
# Learned 599 from 9848!
# Learned 600 from 9848!
# Learned 601 from 9848!
# Learned 602 from 9848!
# Learned 603 from 9848!
# Learned 604 from 9848!
# Learned 605 from 9848!
# Learned 606 from 9848!
# Learned 607 from 9848!
# Learned 608 from 9848!
# Learned 609 from 9848!
# Learned 610 from 9848!
# Learned 611 from 9848!
# Learned 612 from 9848!
# Learned 613 from 9848!
# Learned 614 from 9848!
# Learned 615 from 9848!
# Learned 616 from 9848!
# Learned 617 from 9848!
# Learned 618 from 9848!
# Learned 619 from 9848!
# Learned 620 from 9848!
# Learned 621 from 9848!
# Learned 622 from 9848!
# Learned 623 from 9848!
# Learned 624 from 9848!
# Learned 625 from 9848!
# Learned 626 from 9848!
# Learned 627 from 9848!
# Learned 628 from 9848!
# Learned 629 from 9848!
# Learned 630 from 9848!
# Learned 631 from 9848!
# Learned 632 from 9848!
# Learned 633 from 9848!
# Learned 634 from 9848!
# Learned 635 from 9848!
# Learned 636 from 9848!
# Learned 637 from 9848!
# Learned 638 from 9848!
# Learned 639 from 9848!
# Learned 640 from 9848!
# Learned 641 from 9848!
# Learned 642 from 9848!
# Learned 643 from 9848!
# Learned 644 from 9848!
# Learned 645 from 9848!
# Learned 646 from 9848!
# Learned 647 from 9848!
# Learned 648 from 9848!
# Learned 649 from 9848!
# Learned 650 from 9848!
# Learned 651 from 9848!
# Learned 652 from 9848!
# Learned 653 from 9848!
# Learned 654 from 9848!
# Learned 655 from 9848!
# Learned 656 from 9848!
# Learned 657 from 9848!
# Learned 658 from 9848!
# Learned 659 from 9848!
# Learned 660 from 9848!
# Learned 661 from 9848!
# Learned 662 from 9848!
# Learned 663 from 9848!
# Learned 664 from 9848!
# Learned 665 from 9848!
# Learned 666 from 9848!
# Learned 667 from 9848!
# Learned 668 from 9848!
# Learned 669 from 9848!
# Learned 670 from 9848!
# Learned 671 from 9848!
# Learned 672 from 9848!
# Learned 673 from 9848!
# Learned 674 from 9848!
# Learned 675 from 9848!
# Learned 676 from 9848!
# Learned 677 from 9848!
# Learned 678 from 9848!
# Learned 679 from 9848!
# Learned 680 from 9848!
# Learned 681 from 9848!
# Learned 682 from 9848!
# Learned 683 from 9848!
# Learned 684 from 9848!
# Learned 685 from 9848!
# Learned 686 from 9848!
# Learned 687 from 9848!
# Learned 688 from 9848!
# Learned 689 from 9848!
# Learned 690 from 9848!
# Learned 691 from 9848!
# Learned 692 from 9848!
# Learned 693 from 9848!
# Learned 694 from 9848!
# Learned 695 from 9848!
# Learned 696 from 9848!
# Learned 697 from 9848!
# Learned 698 from 9848!
# Learned 699 from 9848!
# Learned 700 from 9848!
# Learned 701 from 9848!
# Learned 702 from 9848!
# Learned 703 from 9848!
# Learned 704 from 9848!
# Learned 705 from 9848!
# Learned 706 from 9848!
# Learned 707 from 9848!
# Learned 708 from 9848!
# Learned 709 from 9848!
# Learned 710 from 9848!
# Learned 711 from 9848!
# Learned 712 from 9848!
# Learned 713 from 9848!
# Learned 714 from 9848!
# Learned 715 from 9848!
# Learned 716 from 9848!
# Learned 717 from 9848!
# Learned 718 from 9848!
# Learned 719 from 9848!
# Learned 720 from 9848!
# Learned 721 from 9848!
# Learned 722 from 9848!
# Learned 723 from 9848!
# Learned 724 from 9848!
# Learned 725 from 9848!
# Learned 726 from 9848!
# Learned 727 from 9848!
# Learned 728 from 9848!
# Learned 729 from 9848!
# Learned 730 from 9848!
# Learned 731 from 9848!
# Learned 732 from 9848!
# Learned 733 from 9848!
# Learned 734 from 9848!
# Learned 735 from 9848!
# Learned 736 from 9848!
# Learned 737 from 9848!
# Learned 738 from 9848!
# Learned 739 from 9848!
# Learned 740 from 9848!
# Learned 741 from 9848!
# Learned 742 from 9848!
# Learned 743 from 9848!
# Learned 744 from 9848!
# Learned 745 from 9848!
# Learned 746 from 9848!
# Learned 747 from 9848!
# Learned 748 from 9848!
# Learned 749 from 9848!
# Learned 750 from 9848!
# Learned 751 from 9848!
# Learned 752 from 9848!
# Learned 753 from 9848!
# Learned 754 from 9848!
# Learned 755 from 9848!
# Learned 756 from 9848!
# Learned 757 from 9848!
# Learned 758 from 9848!
# Learned 759 from 9848!
# Learned 760 from 9848!
# Learned 761 from 9848!
# Learned 762 from 9848!
# Learned 763 from 9848!
# Learned 764 from 9848!
# Learned 765 from 9848!
# Learned 766 from 9848!
# Learned 767 from 9848!
# Learned 768 from 9848!
# Learned 769 from 9848!
# Learned 770 from 9848!
# Learned 771 from 9848!
# Learned 772 from 9848!
# Learned 773 from 9848!
# Learned 774 from 9848!
# Learned 775 from 9848!
# Learned 776 from 9848!
# Learned 777 from 9848!
# Learned 778 from 9848!
# Learned 779 from 9848!
# Learned 780 from 9848!
# Learned 781 from 9848!
# Learned 782 from 9848!
# Learned 783 from 9848!
# Learned 784 from 9848!
# Learned 785 from 9848!
# Learned 786 from 9848!
# Learned 787 from 9848!
# Learned 788 from 9848!
# Learned 789 from 9848!
# Learned 790 from 9848!
# Learned 791 from 9848!
# Learned 792 from 9848!
# Learned 793 from 9848!
# Learned 794 from 9848!
# Learned 795 from 9848!
# Learned 796 from 9848!
# Learned 797 from 9848!
# Learned 798 from 9848!
# Learned 799 from 9848!
# Learned 800 from 9848!
# Learned 801 from 9848!
# Learned 802 from 9848!
# Learned 803 from 9848!
# Learned 804 from 9848!
# Learned 805 from 9848!
# Learned 806 from 9848!
# Learned 807 from 9848!
# Learned 808 from 9848!
# Learned 809 from 9848!
# Learned 810 from 9848!
# Learned 811 from 9848!
# Learned 812 from 9848!
# Learned 813 from 9848!
# Learned 814 from 9848!
# Learned 815 from 9848!
# Learned 816 from 9848!
# Learned 817 from 9848!
# Learned 818 from 9848!
# Learned 819 from 9848!
# Learned 820 from 9848!
# Learned 821 from 9848!
# Learned 822 from 9848!
# Learned 823 from 9848!
# Learned 824 from 9848!
# Learned 825 from 9848!
# Learned 826 from 9848!
# Learned 827 from 9848!
# Learned 828 from 9848!
# Learned 829 from 9848!
# Learned 830 from 9848!
# Learned 831 from 9848!
# Learned 832 from 9848!
# Learned 833 from 9848!
# Learned 834 from 9848!
# Learned 835 from 9848!
# Learned 836 from 9848!
# Learned 837 from 9848!
# Learned 838 from 9848!
# Learned 839 from 9848!
# Learned 840 from 9848!
# Learned 841 from 9848!
# Learned 842 from 9848!
# Learned 843 from 9848!
# Learned 844 from 9848!
# Learned 845 from 9848!
# Learned 846 from 9848!
# Learned 847 from 9848!
# Learned 848 from 9848!
# Learned 849 from 9848!
# Learned 850 from 9848!
# Learned 851 from 9848!
# Learned 852 from 9848!
# Learned 853 from 9848!
# Learned 854 from 9848!
# Learned 855 from 9848!
# Learned 856 from 9848!
# Learned 857 from 9848!
# Learned 858 from 9848!
# Learned 859 from 9848!
# Learned 860 from 9848!
# Learned 861 from 9848!
# Learned 862 from 9848!
# Learned 863 from 9848!
# Learned 864 from 9848!
# Learned 865 from 9848!
# Learned 866 from 9848!
# Learned 867 from 9848!
# Learned 868 from 9848!
# Learned 869 from 9848!
# Learned 870 from 9848!
# Learned 871 from 9848!
# Learned 872 from 9848!
# Learned 873 from 9848!
# Learned 874 from 9848!
# Learned 875 from 9848!
# Learned 876 from 9848!
# Learned 877 from 9848!
# Learned 878 from 9848!
# Learned 879 from 9848!
# Learned 880 from 9848!
# Learned 881 from 9848!
# Learned 882 from 9848!
# Learned 883 from 9848!
# Learned 884 from 9848!
# Learned 885 from 9848!
# Learned 886 from 9848!
# Learned 887 from 9848!
# Learned 888 from 9848!
# Learned 889 from 9848!
# Learned 890 from 9848!
# Learned 891 from 9848!
# Learned 892 from 9848!
# Learned 893 from 9848!
# Learned 894 from 9848!
# Learned 895 from 9848!
# Learned 896 from 9848!
# Learned 897 from 9848!
# Learned 898 from 9848!
# Learned 899 from 9848!
# Learned 900 from 9848!
# Learned 901 from 9848!
# Learned 902 from 9848!
# Learned 903 from 9848!
# Learned 904 from 9848!
# Learned 905 from 9848!
# Learned 906 from 9848!
# Learned 907 from 9848!
# Learned 908 from 9848!
# Learned 909 from 9848!
# Learned 910 from 9848!
# Learned 911 from 9848!
# Learned 912 from 9848!
# Learned 913 from 9848!
# Learned 914 from 9848!
# Learned 915 from 9848!
# Learned 916 from 9848!
# Learned 917 from 9848!
# Learned 918 from 9848!
# Learned 919 from 9848!
# Learned 920 from 9848!
# Learned 921 from 9848!
# Learned 922 from 9848!
# Learned 923 from 9848!
# Learned 924 from 9848!
# Learned 925 from 9848!
# Learned 926 from 9848!
# Learned 927 from 9848!
# Learned 928 from 9848!
# Learned 929 from 9848!
# Learned 930 from 9848!
# Learned 931 from 9848!
# Learned 932 from 9848!
# Learned 933 from 9848!
# Learned 934 from 9848!
# Learned 935 from 9848!
# Learned 936 from 9848!
# Learned 937 from 9848!
# Learned 938 from 9848!
# Learned 939 from 9848!
# Learned 940 from 9848!
# Learned 941 from 9848!
# Learned 942 from 9848!
# Learned 943 from 9848!
# Learned 944 from 9848!
# Learned 945 from 9848!
# Learned 946 from 9848!
# Learned 947 from 9848!
# Learned 948 from 9848!
# Learned 949 from 9848!
# Learned 950 from 9848!
# Learned 951 from 9848!
# Learned 952 from 9848!
# Learned 953 from 9848!
# Learned 954 from 9848!
# Learned 955 from 9848!
# Learned 956 from 9848!
# Learned 957 from 9848!
# Learned 958 from 9848!
# Learned 959 from 9848!
# Learned 960 from 9848!
# Learned 961 from 9848!
# Learned 962 from 9848!
# Learned 963 from 9848!
# Learned 964 from 9848!
# Learned 965 from 9848!
# Learned 966 from 9848!
# Learned 967 from 9848!
# Learned 968 from 9848!
# Learned 969 from 9848!
# Learned 970 from 9848!
# Learned 971 from 9848!
# Learned 972 from 9848!
# Learned 973 from 9848!
# Learned 974 from 9848!
# Learned 975 from 9848!
# Learned 976 from 9848!
# Learned 977 from 9848!
# Learned 978 from 9848!
# Learned 979 from 9848!
# Learned 980 from 9848!
# Learned 981 from 9848!
# Learned 982 from 9848!
# Learned 983 from 9848!
# Learned 984 from 9848!
# Learned 985 from 9848!
# Learned 986 from 9848!
# Learned 987 from 9848!
# Learned 988 from 9848!
# Learned 989 from 9848!
# Learned 990 from 9848!
# Learned 991 from 9848!
# Learned 992 from 9848!
# Learned 993 from 9848!
# Learned 994 from 9848!
# Learned 995 from 9848!
# Learned 996 from 9848!
# Learned 997 from 9848!
# Learned 998 from 9848!
# Learned 999 from 9848!
# Learned 1000 from 9848!
# Learned 1001 from 9848!
# Learned 1002 from 9848!
# Learned 1003 from 9848!
# Learned 1004 from 9848!
# Learned 1005 from 9848!
# Learned 1006 from 9848!
# Learned 1007 from 9848!
# Learned 1008 from 9848!
# Learned 1009 from 9848!
# Learned 1010 from 9848!
# Learned 1011 from 9848!
# Learned 1012 from 9848!
# Learned 1013 from 9848!
# Learned 1014 from 9848!
# Learned 1015 from 9848!
# Learned 1016 from 9848!
# Learned 1017 from 9848!
# Learned 1018 from 9848!
# Learned 1019 from 9848!
# Learned 1020 from 9848!
# Learned 1021 from 9848!
# Learned 1022 from 9848!
# Learned 1023 from 9848!
# Learned 1024 from 9848!
# Learned 1025 from 9848!
# Learned 1026 from 9848!
# Learned 1027 from 9848!
# Learned 1028 from 9848!
# Learned 1029 from 9848!
# Learned 1030 from 9848!
# Learned 1031 from 9848!
# Learned 1032 from 9848!
# Learned 1033 from 9848!
# Learned 1034 from 9848!
# Learned 1035 from 9848!
# Learned 1036 from 9848!
# Learned 1037 from 9848!
# Learned 1038 from 9848!
# Learned 1039 from 9848!
# Learned 1040 from 9848!
# Learned 1041 from 9848!
# Learned 1042 from 9848!
# Learned 1043 from 9848!
# Learned 1044 from 9848!
# Learned 1045 from 9848!
# Learned 1046 from 9848!
# Learned 1047 from 9848!
# Learned 1048 from 9848!
# Learned 1049 from 9848!
# Learned 1050 from 9848!
# Learned 1051 from 9848!
# Learned 1052 from 9848!
# Learned 1053 from 9848!
# Learned 1054 from 9848!
# Learned 1055 from 9848!
# Learned 1056 from 9848!
# Learned 1057 from 9848!
# Learned 1058 from 9848!
# Learned 1059 from 9848!
# Learned 1060 from 9848!
# Learned 1061 from 9848!
# Learned 1062 from 9848!
# Learned 1063 from 9848!
# Learned 1064 from 9848!
# Learned 1065 from 9848!
# Learned 1066 from 9848!
# Learned 1067 from 9848!
# Learned 1068 from 9848!
# Learned 1069 from 9848!
# Learned 1070 from 9848!
# Learned 1071 from 9848!
# Learned 1072 from 9848!
# Learned 1073 from 9848!
# Learned 1074 from 9848!
# Learned 1075 from 9848!
# Learned 1076 from 9848!
# Learned 1077 from 9848!
# Learned 1078 from 9848!
# Learned 1079 from 9848!
# Learned 1080 from 9848!
# Learned 1081 from 9848!
# Learned 1082 from 9848!
# Learned 1083 from 9848!
# Learned 1084 from 9848!
# Learned 1085 from 9848!
# Learned 1086 from 9848!
# Learned 1087 from 9848!
# Learned 1088 from 9848!
# Learned 1089 from 9848!
# Learned 1090 from 9848!
# Learned 1091 from 9848!
# Learned 1092 from 9848!
# Learned 1093 from 9848!
# Learned 1094 from 9848!
# Learned 1095 from 9848!
# Learned 1096 from 9848!
# Learned 1097 from 9848!
# Learned 1098 from 9848!
# Learned 1099 from 9848!
# Learned 1100 from 9848!
# Learned 1101 from 9848!
# Learned 1102 from 9848!
# Learned 1103 from 9848!
# Learned 1104 from 9848!
# Learned 1105 from 9848!
# Learned 1106 from 9848!
# Learned 1107 from 9848!
# Learned 1108 from 9848!
# Learned 1109 from 9848!
# Learned 1110 from 9848!
# Learned 1111 from 9848!
# Learned 1112 from 9848!
# Learned 1113 from 9848!
# Learned 1114 from 9848!
# Learned 1115 from 9848!
# Learned 1116 from 9848!
# Learned 1117 from 9848!
# Learned 1118 from 9848!
# Learned 1119 from 9848!
# Learned 1120 from 9848!
# Learned 1121 from 9848!
# Learned 1122 from 9848!
# Learned 1123 from 9848!
# Learned 1124 from 9848!
# Learned 1125 from 9848!
# Learned 1126 from 9848!
# Learned 1127 from 9848!
# Learned 1128 from 9848!
# Learned 1129 from 9848!
# Learned 1130 from 9848!
# Learned 1131 from 9848!
# Learned 1132 from 9848!
# Learned 1133 from 9848!
# Learned 1134 from 9848!
# Learned 1135 from 9848!
# Learned 1136 from 9848!
# Learned 1137 from 9848!
# Learned 1138 from 9848!
# Learned 1139 from 9848!
# Learned 1140 from 9848!
# Learned 1141 from 9848!
# Learned 1142 from 9848!
# Learned 1143 from 9848!
# Learned 1144 from 9848!
# Learned 1145 from 9848!
# Learned 1146 from 9848!
# Learned 1147 from 9848!
# Learned 1148 from 9848!
# Learned 1149 from 9848!
# Learned 1150 from 9848!
# Learned 1151 from 9848!
# Learned 1152 from 9848!
# Learned 1153 from 9848!
# Learned 1154 from 9848!
# Learned 1155 from 9848!
# Learned 1156 from 9848!
# Learned 1157 from 9848!
# Learned 1158 from 9848!
# Learned 1159 from 9848!
# Learned 1160 from 9848!
# Learned 1161 from 9848!
# Learned 1162 from 9848!
# Learned 1163 from 9848!
# Learned 1164 from 9848!
# Learned 1165 from 9848!
# Learned 1166 from 9848!
# Learned 1167 from 9848!
# Learned 1168 from 9848!
# Learned 1169 from 9848!
# Learned 1170 from 9848!
# Learned 1171 from 9848!
# Learned 1172 from 9848!
# Learned 1173 from 9848!
# Learned 1174 from 9848!
# Learned 1175 from 9848!
# Learned 1176 from 9848!
# Learned 1177 from 9848!
# Learned 1178 from 9848!
# Learned 1179 from 9848!
# Learned 1180 from 9848!
# Learned 1181 from 9848!
# Learned 1182 from 9848!
# Learned 1183 from 9848!
# Learned 1184 from 9848!
# Learned 1185 from 9848!
# Learned 1186 from 9848!
# Learned 1187 from 9848!
# Learned 1188 from 9848!
# Learned 1189 from 9848!
# Learned 1190 from 9848!
# Learned 1191 from 9848!
# Learned 1192 from 9848!
# Learned 1193 from 9848!
# Learned 1194 from 9848!
# Learned 1195 from 9848!
# Learned 1196 from 9848!
# Learned 1197 from 9848!
# Learned 1198 from 9848!
# Learned 1199 from 9848!
# Learned 1200 from 9848!
# Learned 1201 from 9848!
# Learned 1202 from 9848!
# Learned 1203 from 9848!
# Learned 1204 from 9848!
# Learned 1205 from 9848!
# Learned 1206 from 9848!
# Learned 1207 from 9848!
# Learned 1208 from 9848!
# Learned 1209 from 9848!
# Learned 1210 from 9848!
# Learned 1211 from 9848!
# Learned 1212 from 9848!
# Learned 1213 from 9848!
# Learned 1214 from 9848!
# Learned 1215 from 9848!
# Learned 1216 from 9848!
# Learned 1217 from 9848!
# Learned 1218 from 9848!
# Learned 1219 from 9848!
# Learned 1220 from 9848!
# Learned 1221 from 9848!
# Learned 1222 from 9848!
# Learned 1223 from 9848!
# Learned 1224 from 9848!
# Learned 1225 from 9848!
# Learned 1226 from 9848!
# Learned 1227 from 9848!
# Learned 1228 from 9848!
# Learned 1229 from 9848!
# Learned 1230 from 9848!
# Learned 1231 from 9848!
# Learned 1232 from 9848!
# Learned 1233 from 9848!
# Learned 1234 from 9848!
# Learned 1235 from 9848!
# Learned 1236 from 9848!
# Learned 1237 from 9848!
# Learned 1238 from 9848!
# Learned 1239 from 9848!
# Learned 1240 from 9848!
# Learned 1241 from 9848!
# Learned 1242 from 9848!
# Learned 1243 from 9848!
# Learned 1244 from 9848!
# Learned 1245 from 9848!
# Learned 1246 from 9848!
# Learned 1247 from 9848!
# Learned 1248 from 9848!
# Learned 1249 from 9848!
# Learned 1250 from 9848!
# Learned 1251 from 9848!
# Learned 1252 from 9848!
# Learned 1253 from 9848!
# Learned 1254 from 9848!
# Learned 1255 from 9848!
# Learned 1256 from 9848!
# Learned 1257 from 9848!
# Learned 1258 from 9848!
# Learned 1259 from 9848!
# Learned 1260 from 9848!
# Learned 1261 from 9848!
# Learned 1262 from 9848!
# Learned 1263 from 9848!
# Learned 1264 from 9848!
# Learned 1265 from 9848!
# Learned 1266 from 9848!
# Learned 1267 from 9848!
# Learned 1268 from 9848!
# Learned 1269 from 9848!
# Learned 1270 from 9848!
# Learned 1271 from 9848!
# Learned 1272 from 9848!
# Learned 1273 from 9848!
# Learned 1274 from 9848!
# Learned 1275 from 9848!
# Learned 1276 from 9848!
# Learned 1277 from 9848!
# Learned 1278 from 9848!
# Learned 1279 from 9848!
# Learned 1280 from 9848!
# Learned 1281 from 9848!
# Learned 1282 from 9848!
# Learned 1283 from 9848!
# Learned 1284 from 9848!
# Learned 1285 from 9848!
# Learned 1286 from 9848!
# Learned 1287 from 9848!
# Learned 1288 from 9848!
# Learned 1289 from 9848!
# Learned 1290 from 9848!
# Learned 1291 from 9848!
# Learned 1292 from 9848!
# Learned 1293 from 9848!
# Learned 1294 from 9848!
# Learned 1295 from 9848!
# Learned 1296 from 9848!
# Learned 1297 from 9848!
# Learned 1298 from 9848!
# Learned 1299 from 9848!
# Learned 1300 from 9848!
# Learned 1301 from 9848!
# Learned 1302 from 9848!
# Learned 1303 from 9848!
# Learned 1304 from 9848!
# Learned 1305 from 9848!
# Learned 1306 from 9848!
# Learned 1307 from 9848!
# Learned 1308 from 9848!
# Learned 1309 from 9848!
# Learned 1310 from 9848!
# Learned 1311 from 9848!
# Learned 1312 from 9848!
# Learned 1313 from 9848!
# Learned 1314 from 9848!
# Learned 1315 from 9848!
# Learned 1316 from 9848!
# Learned 1317 from 9848!
# Learned 1318 from 9848!
# Learned 1319 from 9848!
# Learned 1320 from 9848!
# Learned 1321 from 9848!
# Learned 1322 from 9848!
# Learned 1323 from 9848!
# Learned 1324 from 9848!
# Learned 1325 from 9848!
# Learned 1326 from 9848!
# Learned 1327 from 9848!
# Learned 1328 from 9848!
# Learned 1329 from 9848!
# Learned 1330 from 9848!
# Learned 1331 from 9848!
# Learned 1332 from 9848!
# Learned 1333 from 9848!
# Learned 1334 from 9848!
# Learned 1335 from 9848!
# Learned 1336 from 9848!
# Learned 1337 from 9848!
# Learned 1338 from 9848!
# Learned 1339 from 9848!
# Learned 1340 from 9848!
# Learned 1341 from 9848!
# Learned 1342 from 9848!
# Learned 1343 from 9848!
# Learned 1344 from 9848!
# Learned 1345 from 9848!
# Learned 1346 from 9848!
# Learned 1347 from 9848!
# Learned 1348 from 9848!
# Learned 1349 from 9848!
# Learned 1350 from 9848!
# Learned 1351 from 9848!
# Learned 1352 from 9848!
# Learned 1353 from 9848!
# Learned 1354 from 9848!
# Learned 1355 from 9848!
# Learned 1356 from 9848!
# Learned 1357 from 9848!
# Learned 1358 from 9848!
# Learned 1359 from 9848!
# Learned 1360 from 9848!
# Learned 1361 from 9848!
# Learned 1362 from 9848!
# Learned 1363 from 9848!
# Learned 1364 from 9848!
# Learned 1365 from 9848!
# Learned 1366 from 9848!
# Learned 1367 from 9848!
# Learned 1368 from 9848!
# Learned 1369 from 9848!
# Learned 1370 from 9848!
# Learned 1371 from 9848!
# Learned 1372 from 9848!
# Learned 1373 from 9848!
# Learned 1374 from 9848!
# Learned 1375 from 9848!
# Learned 1376 from 9848!
# Learned 1377 from 9848!
# Learned 1378 from 9848!
# Learned 1379 from 9848!
# Learned 1380 from 9848!
# Learned 1381 from 9848!
# Learned 1382 from 9848!
# Learned 1383 from 9848!
# Learned 1384 from 9848!
# Learned 1385 from 9848!
# Learned 1386 from 9848!
# Learned 1387 from 9848!
# Learned 1388 from 9848!
# Learned 1389 from 9848!
# Learned 1390 from 9848!
# Learned 1391 from 9848!
# Learned 1392 from 9848!
# Learned 1393 from 9848!
# Learned 1394 from 9848!
# Learned 1395 from 9848!
# Learned 1396 from 9848!
# Learned 1397 from 9848!
# Learned 1398 from 9848!
# Learned 1399 from 9848!
# Learned 1400 from 9848!
# Learned 1401 from 9848!
# Learned 1402 from 9848!
# Learned 1403 from 9848!
# Learned 1404 from 9848!
# Learned 1405 from 9848!
# Learned 1406 from 9848!
# Learned 1407 from 9848!
# Learned 1408 from 9848!
# Learned 1409 from 9848!
# Learned 1410 from 9848!
# Learned 1411 from 9848!
# Learned 1412 from 9848!
# Learned 1413 from 9848!
# Learned 1414 from 9848!
# Learned 1415 from 9848!
# Learned 1416 from 9848!
# Learned 1417 from 9848!
# Learned 1418 from 9848!
# Learned 1419 from 9848!
# Learned 1420 from 9848!
# Learned 1421 from 9848!
# Learned 1422 from 9848!
# Learned 1423 from 9848!
# Learned 1424 from 9848!
# Learned 1425 from 9848!
# Learned 1426 from 9848!
# Learned 1427 from 9848!
# Learned 1428 from 9848!
# Learned 1429 from 9848!
# Learned 1430 from 9848!
# Learned 1431 from 9848!
# Learned 1432 from 9848!
# Learned 1433 from 9848!
# Learned 1434 from 9848!
# Learned 1435 from 9848!
# Learned 1436 from 9848!
# Learned 1437 from 9848!
# Learned 1438 from 9848!
# Learned 1439 from 9848!
# Learned 1440 from 9848!
# Learned 1441 from 9848!
# Learned 1442 from 9848!
# Learned 1443 from 9848!
# Learned 1444 from 9848!
# Learned 1445 from 9848!
# Learned 1446 from 9848!
# Learned 1447 from 9848!
# Learned 1448 from 9848!
# Learned 1449 from 9848!
# Learned 1450 from 9848!
# Learned 1451 from 9848!
# Learned 1452 from 9848!
# Learned 1453 from 9848!
# Learned 1454 from 9848!
# Learned 1455 from 9848!
# Learned 1456 from 9848!
# Learned 1457 from 9848!
# Learned 1458 from 9848!
# Learned 1459 from 9848!
# Learned 1460 from 9848!
# Learned 1461 from 9848!
# Learned 1462 from 9848!
# Learned 1463 from 9848!
# Learned 1464 from 9848!
# Learned 1465 from 9848!
# Learned 1466 from 9848!
# Learned 1467 from 9848!
# Learned 1468 from 9848!
# Learned 1469 from 9848!
# Learned 1470 from 9848!
# Learned 1471 from 9848!
# Learned 1472 from 9848!
# Learned 1473 from 9848!
# Learned 1474 from 9848!
# Learned 1475 from 9848!
# Learned 1476 from 9848!
# Learned 1477 from 9848!
# Learned 1478 from 9848!
# Learned 1479 from 9848!
# Learned 1480 from 9848!
# Learned 1481 from 9848!
# Learned 1482 from 9848!
# Learned 1483 from 9848!
# Learned 1484 from 9848!
# Learned 1485 from 9848!
# Learned 1486 from 9848!
# Learned 1487 from 9848!
# Learned 1488 from 9848!
# Learned 1489 from 9848!
# Learned 1490 from 9848!
# Learned 1491 from 9848!
# Learned 1492 from 9848!
# Learned 1493 from 9848!
# Learned 1494 from 9848!
# Learned 1495 from 9848!
# Learned 1496 from 9848!
# Learned 1497 from 9848!
# Learned 1498 from 9848!
# Learned 1499 from 9848!
# Learned 1500 from 9848!
# Learned 1501 from 9848!
# Learned 1502 from 9848!
# Learned 1503 from 9848!
# Learned 1504 from 9848!
# Learned 1505 from 9848!
# Learned 1506 from 9848!
# Learned 1507 from 9848!
# Learned 1508 from 9848!
# Learned 1509 from 9848!
# Learned 1510 from 9848!
# Learned 1511 from 9848!
# Learned 1512 from 9848!
# Learned 1513 from 9848!
# Learned 1514 from 9848!
# Learned 1515 from 9848!
# Learned 1516 from 9848!
# Learned 1517 from 9848!
# Learned 1518 from 9848!
# Learned 1519 from 9848!
# Learned 1520 from 9848!
# Learned 1521 from 9848!
# Learned 1522 from 9848!
# Learned 1523 from 9848!
# Learned 1524 from 9848!
# Learned 1525 from 9848!
# Learned 1526 from 9848!
# Learned 1527 from 9848!
# Learned 1528 from 9848!
# Learned 1529 from 9848!
# Learned 1530 from 9848!
# Learned 1531 from 9848!
# Learned 1532 from 9848!
# Learned 1533 from 9848!
# Learned 1534 from 9848!
# Learned 1535 from 9848!
# Learned 1536 from 9848!
# Learned 1537 from 9848!
# Learned 1538 from 9848!
# Learned 1539 from 9848!
# Learned 1540 from 9848!
# Learned 1541 from 9848!
# Learned 1542 from 9848!
# Learned 1543 from 9848!
# Learned 1544 from 9848!
# Learned 1545 from 9848!
# Learned 1546 from 9848!
# Learned 1547 from 9848!
# Learned 1548 from 9848!
# Learned 1549 from 9848!
# Learned 1550 from 9848!
# Learned 1551 from 9848!
# Learned 1552 from 9848!
# Learned 1553 from 9848!
# Learned 1554 from 9848!
# Learned 1555 from 9848!
# Learned 1556 from 9848!
# Learned 1557 from 9848!
# Learned 1558 from 9848!
# Learned 1559 from 9848!
# Learned 1560 from 9848!
# Learned 1561 from 9848!
# Learned 1562 from 9848!
# Learned 1563 from 9848!
# Learned 1564 from 9848!
# Learned 1565 from 9848!
# Learned 1566 from 9848!
# Learned 1567 from 9848!
# Learned 1568 from 9848!
# Learned 1569 from 9848!
# Learned 1570 from 9848!
# Learned 1571 from 9848!
# Learned 1572 from 9848!
# Learned 1573 from 9848!
# Learned 1574 from 9848!
# Learned 1575 from 9848!
# Learned 1576 from 9848!
# Learned 1577 from 9848!
# Learned 1578 from 9848!
# Learned 1579 from 9848!
# Learned 1580 from 9848!
# Learned 1581 from 9848!
# Learned 1582 from 9848!
# Learned 1583 from 9848!
# Learned 1584 from 9848!
# Learned 1585 from 9848!
# Learned 1586 from 9848!
# Learned 1587 from 9848!
# Learned 1588 from 9848!
# Learned 1589 from 9848!
# Learned 1590 from 9848!
# Learned 1591 from 9848!
# Learned 1592 from 9848!
# Learned 1593 from 9848!
# Learned 1594 from 9848!
# Learned 1595 from 9848!
# Learned 1596 from 9848!
# Learned 1597 from 9848!
# Learned 1598 from 9848!
# Learned 1599 from 9848!
# Learned 1600 from 9848!
# Learned 1601 from 9848!
# Learned 1602 from 9848!
# Learned 1603 from 9848!
# Learned 1604 from 9848!
# Learned 1605 from 9848!
# Learned 1606 from 9848!
# Learned 1607 from 9848!
# Learned 1608 from 9848!
# Learned 1609 from 9848!
# Learned 1610 from 9848!
# Learned 1611 from 9848!
# Learned 1612 from 9848!
# Learned 1613 from 9848!
# Learned 1614 from 9848!
# Learned 1615 from 9848!
# Learned 1616 from 9848!
# Learned 1617 from 9848!
# Learned 1618 from 9848!
# Learned 1619 from 9848!
# Learned 1620 from 9848!
# Learned 1621 from 9848!
# Learned 1622 from 9848!
# Learned 1623 from 9848!
# Learned 1624 from 9848!
# Learned 1625 from 9848!
# Learned 1626 from 9848!
# Learned 1627 from 9848!
# Learned 1628 from 9848!
# Learned 1629 from 9848!
# Learned 1630 from 9848!
# Learned 1631 from 9848!
# Learned 1632 from 9848!
# Learned 1633 from 9848!
# Learned 1634 from 9848!
# Learned 1635 from 9848!
# Learned 1636 from 9848!
# Learned 1637 from 9848!
# Learned 1638 from 9848!
# Learned 1639 from 9848!
# Learned 1640 from 9848!
# Learned 1641 from 9848!
# Learned 1642 from 9848!
# Learned 1643 from 9848!
# Learned 1644 from 9848!
# Learned 1645 from 9848!
# Learned 1646 from 9848!
# Learned 1647 from 9848!
# Learned 1648 from 9848!
# Learned 1649 from 9848!
# Learned 1650 from 9848!
# Learned 1651 from 9848!
# Learned 1652 from 9848!
# Learned 1653 from 9848!
# Learned 1654 from 9848!
# Learned 1655 from 9848!
# Learned 1656 from 9848!
# Learned 1657 from 9848!
# Learned 1658 from 9848!
# Learned 1659 from 9848!
# Learned 1660 from 9848!
# Learned 1661 from 9848!
# Learned 1662 from 9848!
# Learned 1663 from 9848!
# Learned 1664 from 9848!
# Learned 1665 from 9848!
# Learned 1666 from 9848!
# Learned 1667 from 9848!
# Learned 1668 from 9848!
# Learned 1669 from 9848!
# Learned 1670 from 9848!
# Learned 1671 from 9848!
# Learned 1672 from 9848!
# Learned 1673 from 9848!
# Learned 1674 from 9848!
# Learned 1675 from 9848!
# Learned 1676 from 9848!
# Learned 1677 from 9848!
# Learned 1678 from 9848!
# Learned 1679 from 9848!
# Learned 1680 from 9848!
# Learned 1681 from 9848!
# Learned 1682 from 9848!
# Learned 1683 from 9848!
# Learned 1684 from 9848!
# Learned 1685 from 9848!
# Learned 1686 from 9848!
# Learned 1687 from 9848!
# Learned 1688 from 9848!
# Learned 1689 from 9848!
# Learned 1690 from 9848!
# Learned 1691 from 9848!
# Learned 1692 from 9848!
# Learned 1693 from 9848!
# Learned 1694 from 9848!
# Learned 1695 from 9848!
# Learned 1696 from 9848!
# Learned 1697 from 9848!
# Learned 1698 from 9848!
# Learned 1699 from 9848!
# Learned 1700 from 9848!
# Learned 1701 from 9848!
# Learned 1702 from 9848!
# Learned 1703 from 9848!
# Learned 1704 from 9848!
# Learned 1705 from 9848!
# Learned 1706 from 9848!
# Learned 1707 from 9848!
# Learned 1708 from 9848!
# Learned 1709 from 9848!
# Learned 1710 from 9848!
# Learned 1711 from 9848!
# Learned 1712 from 9848!
# Learned 1713 from 9848!
# Learned 1714 from 9848!
# Learned 1715 from 9848!
# Learned 1716 from 9848!
# Learned 1717 from 9848!
# Learned 1718 from 9848!
# Learned 1719 from 9848!
# Learned 1720 from 9848!
# Learned 1721 from 9848!
# Learned 1722 from 9848!
# Learned 1723 from 9848!
# Learned 1724 from 9848!
# Learned 1725 from 9848!
# Learned 1726 from 9848!
# Learned 1727 from 9848!
# Learned 1728 from 9848!
# Learned 1729 from 9848!
# Learned 1730 from 9848!
# Learned 1731 from 9848!
# Learned 1732 from 9848!
# Learned 1733 from 9848!
# Learned 1734 from 9848!
# Learned 1735 from 9848!
# Learned 1736 from 9848!
# Learned 1737 from 9848!
# Learned 1738 from 9848!
# Learned 1739 from 9848!
# Learned 1740 from 9848!
# Learned 1741 from 9848!
# Learned 1742 from 9848!
# Learned 1743 from 9848!
# Learned 1744 from 9848!
# Learned 1745 from 9848!
# Learned 1746 from 9848!
# Learned 1747 from 9848!
# Learned 1748 from 9848!
# Learned 1749 from 9848!
# Learned 1750 from 9848!
# Learned 1751 from 9848!
# Learned 1752 from 9848!
# Learned 1753 from 9848!
# Learned 1754 from 9848!
# Learned 1755 from 9848!
# Learned 1756 from 9848!
# Learned 1757 from 9848!
# Learned 1758 from 9848!
# Learned 1759 from 9848!
# Learned 1760 from 9848!
# Learned 1761 from 9848!
# Learned 1762 from 9848!
# Learned 1763 from 9848!
# Learned 1764 from 9848!
# Learned 1765 from 9848!
# Learned 1766 from 9848!
# Learned 1767 from 9848!
# Learned 1768 from 9848!
# Learned 1769 from 9848!
# Learned 1770 from 9848!
# Learned 1771 from 9848!
# Learned 1772 from 9848!
# Learned 1773 from 9848!
# Learned 1774 from 9848!
# Learned 1775 from 9848!
# Learned 1776 from 9848!
# Learned 1777 from 9848!
# Learned 1778 from 9848!
# Learned 1779 from 9848!
# Learned 1780 from 9848!
# Learned 1781 from 9848!
# Learned 1782 from 9848!
# Learned 1783 from 9848!
# Learned 1784 from 9848!
# Learned 1785 from 9848!
# Learned 1786 from 9848!
# Learned 1787 from 9848!
# Learned 1788 from 9848!
# Learned 1789 from 9848!
# Learned 1790 from 9848!
# Learned 1791 from 9848!
# Learned 1792 from 9848!
# Learned 1793 from 9848!
# Learned 1794 from 9848!
# Learned 1795 from 9848!
# Learned 1796 from 9848!
# Learned 1797 from 9848!
# Learned 1798 from 9848!
# Learned 1799 from 9848!
# Learned 1800 from 9848!
# Learned 1801 from 9848!
# Learned 1802 from 9848!
# Learned 1803 from 9848!
# Learned 1804 from 9848!
# Learned 1805 from 9848!
# Learned 1806 from 9848!
# Learned 1807 from 9848!
# Learned 1808 from 9848!
# Learned 1809 from 9848!
# Learned 1810 from 9848!
# Learned 1811 from 9848!
# Learned 1812 from 9848!
# Learned 1813 from 9848!
# Learned 1814 from 9848!
# Learned 1815 from 9848!
# Learned 1816 from 9848!
# Learned 1817 from 9848!
# Learned 1818 from 9848!
# Learned 1819 from 9848!
# Learned 1820 from 9848!
# Learned 1821 from 9848!
# Learned 1822 from 9848!
# Learned 1823 from 9848!
# Learned 1824 from 9848!
# Learned 1825 from 9848!
# Learned 1826 from 9848!
# Learned 1827 from 9848!
# Learned 1828 from 9848!
# Learned 1829 from 9848!
# Learned 1830 from 9848!
# Learned 1831 from 9848!
# Learned 1832 from 9848!
# Learned 1833 from 9848!
# Learned 1834 from 9848!
# Learned 1835 from 9848!
# Learned 1836 from 9848!
# Learned 1837 from 9848!
# Learned 1838 from 9848!
# Learned 1839 from 9848!
# Learned 1840 from 9848!
# Learned 1841 from 9848!
# Learned 1842 from 9848!
# Learned 1843 from 9848!
# Learned 1844 from 9848!
# Learned 1845 from 9848!
# Learned 1846 from 9848!
# Learned 1847 from 9848!
# Learned 1848 from 9848!
# Learned 1849 from 9848!
# Learned 1850 from 9848!
# Learned 1851 from 9848!
# Learned 1852 from 9848!
# Learned 1853 from 9848!
# Learned 1854 from 9848!
# Learned 1855 from 9848!
# Learned 1856 from 9848!
# Learned 1857 from 9848!
# Learned 1858 from 9848!
# Learned 1859 from 9848!
# Learned 1860 from 9848!
# Learned 1861 from 9848!
# Learned 1862 from 9848!
# Learned 1863 from 9848!
# Learned 1864 from 9848!
# Learned 1865 from 9848!
# Learned 1866 from 9848!
# Learned 1867 from 9848!
# Learned 1868 from 9848!
# Learned 1869 from 9848!
# Learned 1870 from 9848!
# Learned 1871 from 9848!
# Learned 1872 from 9848!
# Learned 1873 from 9848!
# Learned 1874 from 9848!
# Learned 1875 from 9848!
# Learned 1876 from 9848!
# Learned 1877 from 9848!
# Learned 1878 from 9848!
# Learned 1879 from 9848!
# Learned 1880 from 9848!
# Learned 1881 from 9848!
# Learned 1882 from 9848!
# Learned 1883 from 9848!
# Learned 1884 from 9848!
# Learned 1885 from 9848!
# Learned 1886 from 9848!
# Learned 1887 from 9848!
# Learned 1888 from 9848!
# Learned 1889 from 9848!
# Learned 1890 from 9848!
# Learned 1891 from 9848!
# Learned 1892 from 9848!
# Learned 1893 from 9848!
# Learned 1894 from 9848!
# Learned 1895 from 9848!
# Learned 1896 from 9848!
# Learned 1897 from 9848!
# Learned 1898 from 9848!
# Learned 1899 from 9848!
# Learned 1900 from 9848!
# Learned 1901 from 9848!
# Learned 1902 from 9848!
# Learned 1903 from 9848!
# Learned 1904 from 9848!
# Learned 1905 from 9848!
# Learned 1906 from 9848!
# Learned 1907 from 9848!
# Learned 1908 from 9848!
# Learned 1909 from 9848!
# Learned 1910 from 9848!
# Learned 1911 from 9848!
# Learned 1912 from 9848!
# Learned 1913 from 9848!
# Learned 1914 from 9848!
# Learned 1915 from 9848!
# Learned 1916 from 9848!
# Learned 1917 from 9848!
# Learned 1918 from 9848!
# Learned 1919 from 9848!
# Learned 1920 from 9848!
# Learned 1921 from 9848!
# Learned 1922 from 9848!
# Learned 1923 from 9848!
# Learned 1924 from 9848!
# Learned 1925 from 9848!
# Learned 1926 from 9848!
# Learned 1927 from 9848!
# Learned 1928 from 9848!
# Learned 1929 from 9848!
# Learned 1930 from 9848!
# Learned 1931 from 9848!
# Learned 1932 from 9848!
# Learned 1933 from 9848!
# Learned 1934 from 9848!
# Learned 1935 from 9848!
# Learned 1936 from 9848!
# Learned 1937 from 9848!
# Learned 1938 from 9848!
# Learned 1939 from 9848!
# Learned 1940 from 9848!
# Learned 1941 from 9848!
# Learned 1942 from 9848!
# Learned 1943 from 9848!
# Learned 1944 from 9848!
# Learned 1945 from 9848!
# Learned 1946 from 9848!
# Learned 1947 from 9848!
# Learned 1948 from 9848!
# Learned 1949 from 9848!
# Learned 1950 from 9848!
# Learned 1951 from 9848!
# Learned 1952 from 9848!
# Learned 1953 from 9848!
# Learned 1954 from 9848!
# Learned 1955 from 9848!
# Learned 1956 from 9848!
# Learned 1957 from 9848!
# Learned 1958 from 9848!
# Learned 1959 from 9848!
# Learned 1960 from 9848!
# Learned 1961 from 9848!
# Learned 1962 from 9848!
# Learned 1963 from 9848!
# Learned 1964 from 9848!
# Learned 1965 from 9848!
# Learned 1966 from 9848!
# Learned 1967 from 9848!
# Learned 1968 from 9848!
# Learned 1969 from 9848!
# Learned 1970 from 9848!
# Learned 1971 from 9848!
# Learned 1972 from 9848!
# Learned 1973 from 9848!
# Learned 1974 from 9848!
# Learned 1975 from 9848!
# Learned 1976 from 9848!
# Learned 1977 from 9848!
# Learned 1978 from 9848!
# Learned 1979 from 9848!
# Learned 1980 from 9848!
# Learned 1981 from 9848!
# Learned 1982 from 9848!
# Learned 1983 from 9848!
# Learned 1984 from 9848!
# Learned 1985 from 9848!
# Learned 1986 from 9848!
# Learned 1987 from 9848!
# Learned 1988 from 9848!
# Learned 1989 from 9848!
# Learned 1990 from 9848!
# Learned 1991 from 9848!
# Learned 1992 from 9848!
# Learned 1993 from 9848!
# Learned 1994 from 9848!
# Learned 1995 from 9848!
# Learned 1996 from 9848!
# Learned 1997 from 9848!
# Learned 1998 from 9848!
# Learned 1999 from 9848!
# Learned 2000 from 9848!
# Learned 2001 from 9848!
# Learned 2002 from 9848!
# Learned 2003 from 9848!
# Learned 2004 from 9848!
# Learned 2005 from 9848!
# Learned 2006 from 9848!
# Learned 2007 from 9848!
# Learned 2008 from 9848!
# Learned 2009 from 9848!
# Learned 2010 from 9848!
# Learned 2011 from 9848!
# Learned 2012 from 9848!
# Learned 2013 from 9848!
# Learned 2014 from 9848!
# Learned 2015 from 9848!
# Learned 2016 from 9848!
# Learned 2017 from 9848!
# Learned 2018 from 9848!
# Learned 2019 from 9848!
# Learned 2020 from 9848!
# Learned 2021 from 9848!
# Learned 2022 from 9848!
# Learned 2023 from 9848!
# Learned 2024 from 9848!
# Learned 2025 from 9848!
# Learned 2026 from 9848!
# Learned 2027 from 9848!
# Learned 2028 from 9848!
# Learned 2029 from 9848!
# Learned 2030 from 9848!
# Learned 2031 from 9848!
# Learned 2032 from 9848!
# Learned 2033 from 9848!
# Learned 2034 from 9848!
# Learned 2035 from 9848!
# Learned 2036 from 9848!
# Learned 2037 from 9848!
# Learned 2038 from 9848!
# Learned 2039 from 9848!
# Learned 2040 from 9848!
# Learned 2041 from 9848!
# Learned 2042 from 9848!
# Learned 2043 from 9848!
# Learned 2044 from 9848!
# Learned 2045 from 9848!
# Learned 2046 from 9848!
# ...
# Learned 2663 from 9848!
# Learned 2664 from 9848!
# Learned 2665 from 9848!
# Learned 2666 from 9848!
# Learned 2667 from 9848!
# Learned 2668 from 9848!
# Learned 2669 from 9848!
# Learned 2670 from 9848!
# Learned 2671 from 9848!
# Learned 2672 from 9848!
# Learned 2673 from 9848!
# Learned 2674 from 9848!
# Learned 2675 from 9848!
# Learned 2676 from 9848!
# Learned 2677 from 9848!
# Learned 2678 from 9848!
# Learned 2679 from 9848!
# Learned 2680 from 9848!
# Learned 2681 from 9848!
# Learned 2682 from 9848!
# Learned 2683 from 9848!
# Learned 2684 from 9848!
# Learned 2685 from 9848!
# Learned 2686 from 9848!
# Learned 2687 from 9848!
# Learned 2688 from 9848!
# Learned 2689 from 9848!
# Learned 2690 from 9848!
# Learned 2691 from 9848!
# Learned 2692 from 9848!
# Learned 2693 from 9848!
# Learned 2694 from 9848!
# Learned 2695 from 9848!
# Learned 2696 from 9848!
# Learned 2697 from 9848!
# Learned 2698 from 9848!
# Learned 2699 from 9848!
# Learned 2700 from 9848!
# Learned 2701 from 9848!
# Learned 2702 from 9848!
# Learned 2703 from 9848!
# Learned 2704 from 9848!
# Learned 2705 from 9848!
# Learned 2706 from 9848!
# Learned 2707 from 9848!
# Learned 2708 from 9848!
# Learned 2709 from 9848!
# Learned 2710 from 9848!
# Learned 2711 from 9848!
# Learned 2712 from 9848!
# Learned 2713 from 9848!
# Learned 2714 from 9848!
# Learned 2715 from 9848!
# Learned 2716 from 9848!
# Learned 2717 from 9848!
# Learned 2718 from 9848!
# Learned 2719 from 9848!
# Learned 2720 from 9848!
# Learned 2721 from 9848!
# Learned 2722 from 9848!
# Learned 2723 from 9848!
# Learned 2724 from 9848!
# Learned 2725 from 9848!
# Learned 2726 from 9848!
# Learned 2727 from 9848!
# Learned 2728 from 9848!
# Learned 2729 from 9848!
# Learned 2730 from 9848!
# Learned 2731 from 9848!
# Learned 2732 from 9848!
# Learned 2733 from 9848!
# Learned 2734 from 9848!
# Learned 2735 from 9848!
# Learned 2736 from 9848!
# Learned 2737 from 9848!
# Learned 2738 from 9848!
# Learned 2739 from 9848!
# Learned 2740 from 9848!
# Learned 2741 from 9848!
# Learned 2742 from 9848!
# Learned 2743 from 9848!
# Learned 2744 from 9848!
# Learned 2745 from 9848!
# Learned 2746 from 9848!
# Learned 2747 from 9848!
# Learned 2748 from 9848!
# Learned 2749 from 9848!
# Learned 2750 from 9848!
# Learned 2751 from 9848!
# Learned 2752 from 9848!
# Learned 2753 from 9848!
# Learned 2754 from 9848!
# Learned 2755 from 9848!
# Learned 2756 from 9848!
# Learned 2757 from 9848!
# Learned 2758 from 9848!
# Learned 2759 from 9848!
# Learned 2760 from 9848!
# Learned 2761 from 9848!
# Learned 2762 from 9848!
# Learned 2763 from 9848!
# Learned 2764 from 9848!
# Learned 2765 from 9848!
# Learned 2766 from 9848!
# Learned 2767 from 9848!
# Learned 2768 from 9848!
# Learned 2769 from 9848!
# Learned 2770 from 9848!
# Learned 2771 from 9848!
# Learned 2772 from 9848!
# Learned 2773 from 9848!
# Learned 2774 from 9848!
# Learned 2775 from 9848!
# Learned 2776 from 9848!
# Learned 2777 from 9848!
# Learned 2778 from 9848!
# Learned 2779 from 9848!
# Learned 2780 from 9848!
# Learned 2781 from 9848!
# Learned 2782 from 9848!
# Learned 2783 from 9848!
# Learned 2784 from 9848!
# Learned 2785 from 9848!
# Learned 2786 from 9848!
# Learned 2787 from 9848!
# Learned 2788 from 9848!
# Learned 2789 from 9848!
# Learned 2790 from 9848!
# Learned 2791 from 9848!
# Learned 2792 from 9848!
# Learned 2793 from 9848!
# Learned 2794 from 9848!
# Learned 2795 from 9848!
# Learned 2796 from 9848!
# Learned 2797 from 9848!
# Learned 2798 from 9848!
# Learned 2799 from 9848!
# Learned 2800 from 9848!
# Learned 2801 from 9848!
# Learned 2802 from 9848!
# Learned 2803 from 9848!
# Learned 2804 from 9848!
# Learned 2805 from 9848!
# Learned 2806 from 9848!
# Learned 2807 from 9848!
# Learned 2808 from 9848!
# Learned 2809 from 9848!
# Learned 2810 from 9848!
# Learned 2811 from 9848!
# Learned 2812 from 9848!
# Learned 2813 from 9848!
# Learned 2814 from 9848!
# Learned 2815 from 9848!
# Learned 2816 from 9848!
# Learned 2817 from 9848!
# Learned 2818 from 9848!
# Learned 2819 from 9848!
# Learned 2820 from 9848!
# Learned 2821 from 9848!
# Learned 2822 from 9848!
# Learned 2823 from 9848!
# Learned 2824 from 9848!
# Learned 2825 from 9848!
# Learned 2826 from 9848!
# Learned 2827 from 9848!
# Learned 2828 from 9848!
# Learned 2829 from 9848!
# Learned 2830 from 9848!
# Learned 2831 from 9848!
# Learned 2832 from 9848!
# Learned 2833 from 9848!
# Learned 2834 from 9848!
# Learned 2835 from 9848!
# Learned 2836 from 9848!
# Learned 2837 from 9848!
# Learned 2838 from 9848!
# Learned 2839 from 9848!
# Learned 2840 from 9848!
# Learned 2841 from 9848!
# Learned 2842 from 9848!
# Learned 2843 from 9848!
# Learned 2844 from 9848!
# Learned 2845 from 9848!
# Learned 2846 from 9848!
# Learned 2847 from 9848!
# Learned 2848 from 9848!
# Learned 2849 from 9848!
# Learned 2850 from 9848!
# Learned 2851 from 9848!
# Learned 2852 from 9848!
# Learned 2853 from 9848!
# Learned 2854 from 9848!
# Learned 2855 from 9848!
# Learned 2856 from 9848!
# Learned 2857 from 9848!
# Learned 2858 from 9848!
# Learned 2859 from 9848!
# Learned 2860 from 9848!
# Learned 2861 from 9848!
# Learned 2862 from 9848!
# Learned 2863 from 9848!
# Learned 2864 from 9848!
# Learned 2865 from 9848!
# Learned 2866 from 9848!
# Learned 2867 from 9848!
# Learned 2868 from 9848!
# Learned 2869 from 9848!
# Learned 2870 from 9848!
# Learned 2871 from 9848!
# Learned 2872 from 9848!
# Learned 2873 from 9848!
# Learned 2874 from 9848!
# Learned 2875 from 9848!
# Learned 2876 from 9848!
# Learned 2877 from 9848!
# Learned 2878 from 9848!
# Learned 2879 from 9848!
# Learned 2880 from 9848!
# Learned 2881 from 9848!
# Learned 2882 from 9848!
# Learned 2883 from 9848!
# Learned 2884 from 9848!
# Learned 2885 from 9848!
# Learned 2886 from 9848!
# Learned 2887 from 9848!
# Learned 2888 from 9848!
# Learned 2889 from 9848!
# Learned 2890 from 9848!
# Learned 2891 from 9848!
# Learned 2892 from 9848!
# Learned 2893 from 9848!
# Learned 2894 from 9848!
# Learned 2895 from 9848!
# Learned 2896 from 9848!
# Learned 2897 from 9848!
# Learned 2898 from 9848!
# Learned 2899 from 9848!
# Learned 2900 from 9848!
# Learned 2901 from 9848!
# Learned 2902 from 9848!
# Learned 2903 from 9848!
# Learned 2904 from 9848!
# Learned 2905 from 9848!
# Learned 2906 from 9848!
# Learned 2907 from 9848!
# Learned 2908 from 9848!
# Learned 2909 from 9848!
# Learned 2910 from 9848!
# Learned 2911 from 9848!
# Learned 2912 from 9848!
# Learned 2913 from 9848!
# Learned 2914 from 9848!
# Learned 2915 from 9848!
# Learned 2916 from 9848!
# Learned 2917 from 9848!
# Learned 2918 from 9848!
# Learned 2919 from 9848!
# Learned 2920 from 9848!
# Learned 2921 from 9848!
# Learned 2922 from 9848!
# Learned 2923 from 9848!
# Learned 2924 from 9848!
# Learned 2925 from 9848!
# Learned 2926 from 9848!
# Learned 2927 from 9848!
# Learned 2928 from 9848!
# Learned 2929 from 9848!
# Learned 2930 from 9848!
# Learned 2931 from 9848!
# Learned 2932 from 9848!
# Learned 2933 from 9848!
# Learned 2934 from 9848!
# Learned 2935 from 9848!
# Learned 2936 from 9848!
# Learned 2937 from 9848!
# Learned 2938 from 9848!
# Learned 2939 from 9848!
# Learned 2940 from 9848!
# Learned 2941 from 9848!
# Learned 2942 from 9848!
# Learned 2943 from 9848!
# Learned 2944 from 9848!
# Learned 2945 from 9848!
# Learned 2946 from 9848!
# Learned 2947 from 9848!
# Learned 2948 from 9848!
# Learned 2949 from 9848!
# Learned 2950 from 9848!
# Learned 2951 from 9848!
# Learned 2952 from 9848!
# Learned 2953 from 9848!
# Learned 2954 from 9848!
# Learned 2955 from 9848!
# Learned 2956 from 9848!
# Learned 2957 from 9848!
# Learned 2958 from 9848!
# Learned 2959 from 9848!
# Learned 2960 from 9848!
# Learned 2961 from 9848!
# Learned 2962 from 9848!
# Learned 2963 from 9848!
# Learned 2964 from 9848!
# Learned 2965 from 9848!
# Learned 2966 from 9848!
# Learned 2967 from 9848!
# Learned 2968 from 9848!
# Learned 2969 from 9848!
# Learned 2970 from 9848!
# Learned 2971 from 9848!
# Learned 2972 from 9848!
# Learned 2973 from 9848!
# Learned 2974 from 9848!
# Learned 2975 from 9848!
# Learned 2976 from 9848!
# Learned 2977 from 9848!
# Learned 2978 from 9848!
# Learned 2979 from 9848!
# Learned 2980 from 9848!
# Learned 2981 from 9848!
# Learned 2982 from 9848!
# Learned 2983 from 9848!
# Learned 2984 from 9848!
# Learned 2985 from 9848!
# Learned 2986 from 9848!
# Learned 2987 from 9848!
# Learned 2988 from 9848!
# Learned 2989 from 9848!
# Learned 2990 from 9848!
# Learned 2991 from 9848!
# Learned 2992 from 9848!
# Learned 2993 from 9848!
# Learned 2994 from 9848!
# Learned 2995 from 9848!
# Learned 2996 from 9848!
# Learned 2997 from 9848!
# Learned 2998 from 9848!
# Learned 2999 from 9848!
# Learned 3000 from 9848!
# Learned 3001 from 9848!
# Learned 3002 from 9848!
# Learned 3003 from 9848!
# Learned 3004 from 9848!
# Learned 3005 from 9848!
# Learned 3006 from 9848!
# Learned 3007 from 9848!
# Learned 3008 from 9848!
# Learned 3009 from 9848!
# Learned 3010 from 9848!
# Learned 3011 from 9848!
# Learned 3012 from 9848!
# Learned 3013 from 9848!
# Learned 3014 from 9848!
# Learned 3015 from 9848!
# Learned 3016 from 9848!
# Learned 3017 from 9848!
# Learned 3018 from 9848!
# Learned 3019 from 9848!
# Learned 3020 from 9848!
# Learned 3021 from 9848!
# Learned 3022 from 9848!
# Learned 3023 from 9848!
# Learned 3024 from 9848!
# Learned 3025 from 9848!
# Learned 3026 from 9848!
# Learned 3027 from 9848!
# Learned 3028 from 9848!
# Learned 3029 from 9848!
# Learned 3030 from 9848!
# Learned 3031 from 9848!
# Learned 3032 from 9848!
# Learned 3033 from 9848!
# Learned 3034 from 9848!
# Learned 3035 from 9848!
# Learned 3036 from 9848!
# Learned 3037 from 9848!
# Learned 3038 from 9848!
# Learned 3039 from 9848!
# Learned 3040 from 9848!
# Learned 3041 from 9848!
# Learned 3042 from 9848!
# Learned 3043 from 9848!
# Learned 3044 from 9848!
# Learned 3045 from 9848!
# Learned 3046 from 9848!
# Learned 3047 from 9848!
# Learned 3048 from 9848!
# Learned 3049 from 9848!
# Learned 3050 from 9848!
# Learned 3051 from 9848!
# Learned 3052 from 9848!
# Learned 3053 from 9848!
# Learned 3054 from 9848!
# Learned 3055 from 9848!
# Learned 3056 from 9848!
# Learned 3057 from 9848!
# Learned 3058 from 9848!
# Learned 3059 from 9848!
# Learned 3060 from 9848!
# Learned 3061 from 9848!
# Learned 3062 from 9848!
# Learned 3063 from 9848!
# Learned 3064 from 9848!
# Learned 3065 from 9848!
# Learned 3066 from 9848!
# Learned 3067 from 9848!
# Learned 3068 from 9848!
# Learned 3069 from 9848!
# Learned 3070 from 9848!
# Learned 3071 from 9848!
# Learned 3072 from 9848!
# Learned 3073 from 9848!
# Learned 3074 from 9848!
# Learned 3075 from 9848!
# Learned 3076 from 9848!
# Learned 3077 from 9848!
# Learned 3078 from 9848!
# Learned 3079 from 9848!
# Learned 3080 from 9848!
# Learned 3081 from 9848!
# Learned 3082 from 9848!
# Learned 3083 from 9848!
# Learned 3084 from 9848!
# Learned 3085 from 9848!
# Learned 3086 from 9848!
# Learned 3087 from 9848!
# Learned 3088 from 9848!
# Learned 3089 from 9848!
# Learned 3090 from 9848!
# Learned 3091 from 9848!
# Learned 3092 from 9848!
# Learned 3093 from 9848!
# Learned 3094 from 9848!
# Learned 3095 from 9848!
# Learned 3096 from 9848!
# Learned 3097 from 9848!
# Learned 3098 from 9848!
# Learned 3099 from 9848!
# Learned 3100 from 9848!
# Learned 3101 from 9848!
# Learned 3102 from 9848!
# Learned 3103 from 9848!
# Learned 3104 from 9848!
# Learned 3105 from 9848!
# Learned 3106 from 9848!
# Learned 3107 from 9848!
# Learned 3108 from 9848!
# Learned 3109 from 9848!
# Learned 3110 from 9848!
# Learned 3111 from 9848!
# Learned 3112 from 9848!
# Learned 3113 from 9848!
# Learned 3114 from 9848!
# Learned 3115 from 9848!
# Learned 3116 from 9848!
# Learned 3117 from 9848!
# Learned 3118 from 9848!
# Learned 3119 from 9848!
# Learned 3120 from 9848!
# Learned 3121 from 9848!
# Learned 3122 from 9848!
# Learned 3123 from 9848!
# Learned 3124 from 9848!
# Learned 3125 from 9848!
# Learned 3126 from 9848!
# Learned 3127 from 9848!
# Learned 3128 from 9848!
# Learned 3129 from 9848!
# Learned 3130 from 9848!
# Learned 3131 from 9848!
# Learned 3132 from 9848!
# Learned 3133 from 9848!
# Learned 3134 from 9848!
# Learned 3135 from 9848!
# Learned 3136 from 9848!
# Learned 3137 from 9848!
# Learned 3138 from 9848!
# Learned 3139 from 9848!
# Learned 3140 from 9848!
# Learned 3141 from 9848!
# Learned 3142 from 9848!
# Learned 3143 from 9848!
# Learned 3144 from 9848!
# Learned 3145 from 9848!
# Learned 3146 from 9848!
# Learned 3147 from 9848!
# Learned 3148 from 9848!
# Learned 3149 from 9848!
# Learned 3150 from 9848!
# Learned 3151 from 9848!
# Learned 3152 from 9848!
# Learned 3153 from 9848!
# Learned 3154 from 9848!
# Learned 3155 from 9848!
# Learned 3156 from 9848!
# Learned 3157 from 9848!
# Learned 3158 from 9848!
# Learned 3159 from 9848!
# Learned 3160 from 9848!
# Learned 3161 from 9848!
# Learned 3162 from 9848!
# Learned 3163 from 9848!
# Learned 3164 from 9848!
# Learned 3165 from 9848!
# Learned 3166 from 9848!
# Learned 3167 from 9848!
# Learned 3168 from 9848!
# Learned 3169 from 9848!
# Learned 3170 from 9848!
# Learned 3171 from 9848!
# Learned 3172 from 9848!
# Learned 3173 from 9848!
# Learned 3174 from 9848!
# Learned 3175 from 9848!
# Learned 3176 from 9848!
# Learned 3177 from 9848!
# Learned 3178 from 9848!
# Learned 3179 from 9848!
# Learned 3180 from 9848!
# Learned 3181 from 9848!
# Learned 3182 from 9848!
# Learned 3183 from 9848!
# Learned 3184 from 9848!
# Learned 3185 from 9848!
# Learned 3186 from 9848!
# Learned 3187 from 9848!
# Learned 3188 from 9848!
# Learned 3189 from 9848!
# Learned 3190 from 9848!
# Learned 3191 from 9848!
# Learned 3192 from 9848!
# Learned 3193 from 9848!
# Learned 3194 from 9848!
# Learned 3195 from 9848!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\gensim\utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     691         try:
# --> 692             _pickle.dump(self, fname_or_handle, protocol=pickle_protocol)
#     693             logger.info("saved %s object", self.__class__.__name__)
#
# TypeError: file must have a 'write' attribute
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-51-255a16098479> in <module>
# ----> 1 doc2vec_trainer(allwords, model_doc, fname)
#       2 #doc2vec_trainer(words_stem, words_stem, model_doc, fname)
#
# <ipython-input-4-1bddb7d00442> in doc2vec_trainer(ws, model_doc, fname, c)
#      10                          epochs=50, report_delay=99999)
#      11         model_doc.alpha -= 0.0002 # adjusting the learning rate
# ---> 12         model_doc.save(fname)
#      13         c+=1
#      14         print('Learned {} from {}!'.format(c, len(ws)))
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in save(self, fname_or_handle, **kwargs)
#     619
#     620         """
# --> 621         super(BaseAny2VecModel, self).save(fname_or_handle, **kwargs)
#     622
#     623
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in save(self, fname_or_handle, separately, sep_limit, ignore, pickle_protocol)
#     693             logger.info("saved %s object", self.__class__.__name__)
#     694         except TypeError:  # `fname_or_handle` does not have write attribute
# --> 695             self._smart_save(fname_or_handle, separately, sep_limit, ignore, pickle_protocol=pickle_protocol)
#     696
#     697
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in _smart_save(self, fname, separately, sep_limit, ignore, pickle_protocol)
#     547                                        compress, subname)
#     548         try:
# --> 549             pickle(self, fname, protocol=pickle_protocol)
#     550         finally:
#     551             # restore attribs handled specially
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in pickle(obj, fname, protocol)
#    1361
#    1362     """
# -> 1363     with open(fname, 'wb') as fout:  # 'b' for binary, needed on Windows
#    1364         _pickle.dump(obj, fout, protocol=protocol)
#    1365
#
# ~\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     306         buffering=buffering,
#     307         encoding=encoding,
# --> 308         errors=errors,
#     309     )
#     310     if fobj is not None:
#
# ~\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     515     #
#     516     if six.PY3:
# --> 517         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     518     elif not open_kwargs:
#     519         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering)
#
# PermissionError: [Errno 13] Permission denied: 'd2v_trainned_allwords.model'

# %%
model_doc = Doc2Vec.load("d2v_trainned_allwords.model")

# %%
model_doc.most_similar(positive=['direito'])
#### Search Engine
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-24c62065f737> in <module>
# ----> 1 model_doc.most_similar(positive=['direito'])
#       2 #### Search Engine
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# ~\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'direito' not in vocabulary"

# %%
keywords = input('Search: ')
# Out:
# Search: acidente de trânsito

# %%
key1 = keywords.strip().lower().split()
key2 = [RSLPStemmer().stem(word.lower()) for word in key1]
#print('Choose words in appropriate format.')
key2
# Out:
# ['acid', 'de', 'trânsit']

# %%
model_doc.most_similar(positive=[key2[0]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-160579f4c93a> in <module>
# ----> 1 model_doc.most_similar(positive=[key2[0]])
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# ~\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'acid' not in vocabulary"

# %%
tokens = 'direito'
new_vector = model_doc.infer_vector(tokens.split() ,alpha=0.001 ,steps = 5)
tagsim = model_doc.docvecs.most_similar([new_vector])[0]

docsim = words[tagsim['acordo']]

print("Document : ", data[docsim.original_number], "\n")

# %%
words
# Out:
# 0       [acordo, despacho, autos, presente, caso, deci...
# 1       [presente, reclamação, conferência, recurso, a...
# 2       [estabelecimento, hospital, tratamento, assist...
# 3       [formação, excepcional, fundamento, art, cpc, ...
# 4       [artigo, ccivil, valor, bens, data, abertura, ...
#                               ...
# 9843    [recurso, excepcional, stj, questão, direito, ...
# 9844    [senhorio, dever, inquilino, gozo, prédio, fin...
# 9845    [matéria, facto, stj, fundamentos, parte, fina...
# 9846    [sede, saneador, sentença, juiz, termos, art, ...
# 9847    [relevância, exclusão, culpa, rés, convicção, ...
# Name: main, Length: 9848, dtype: object

# %%
new_vector = model.infer_vector(tokens.split() ,alpha=0.001 ,steps = 5)
sims = model.docvecs.most_similar([new_vector], topn=model.docvecs.count)

print("Most : " , data[alldocs[sims[0][0]].original_number], "\n") 
print("Median : " , data[alldocs[sims[17000][0]].original_number], "\n")
print("Least : " , data[alldocs[sims[-1][0]].original_number])
